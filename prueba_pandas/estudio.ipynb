# %%
import pandas as pd

tabla = pd.read_csv("tycho-mini.csv",sep=",")
display(tabla)
# Out:
#         epi_week country state           loc loc_type  \
# 0         188824      US    PA  PHILADELPHIA     CITY
# 1         188824      US    PA  PHILADELPHIA     CITY
# 2         188824      US    PA  PHILADELPHIA     CITY
# 3         188826      US    PA  PHILADELPHIA     CITY
# 4         188826      US    PA  PHILADELPHIA     CITY
# ...          ...     ...   ...           ...      ...
# 999995    192709      US    IN    FORT WAYNE     CITY
# 999996    192709      US    IN    FORT WAYNE     CITY
# 999997    192709      US    IN    FORT WAYNE     CITY
# 999998    192709      US    IN    FORT WAYNE     CITY
# 999999    192709      US    IN    FORT WAYNE     CITY
#
#                               disease   event  number   from_date     to_date  \
# 0       TYPHOID FEVER [ENTERIC FEVER]  DEATHS      14  1888-06-10  1888-06-16
# 1                       SCARLET FEVER  DEATHS       4  1888-06-10  1888-06-16
# 2                          DIPHTHERIA  DEATHS       4  1888-06-10  1888-06-16
# ...

# %%
import pandas as pd
tabla = pd.read_csv("tycho-mini.csv",sep=",")
state = tabla["loc_type"]
tabla.sort_values(by=["number"],ascending=False)
tabla["event"].where()["DEATHS"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [16], line 5
#       3 state = tabla["loc_type"]
#       4 tabla.sort_values(by=["number"],ascending=False)
# ----> 5 tabla["event"]["DEATHS"]
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     <a href='file:///home/arnaualbert/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/core/series.py?line=954'>955</a>     return self._values[key]
#     <a href='file:///home/arnaualbert/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/core/series.py?line=956'>957</a> elif key_is_scalar:
# --> <a href='file:///home/arnaualbert/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/core/series.py?line=957'>958</a>     return self._get_value(key)
# ...

# %%
import pandas as pd
#coge solo los valores unicos
tabla = pd.read_csv("tycho-mini.csv",sep=",")
tabla["disease"].unique().tolist()
# Out:
# ['TYPHOID FEVER [ENTERIC FEVER]',
#  'SCARLET FEVER',
#  'DIPHTHERIA',
#  'WHOOPING COUGH [PERTUSSIS]',
#  'TYPHUS FEVER',
#  'YELLOW FEVER',
#  'CHICKENPOX [VARICELLA]',
#  'VARIOLOID',
#  'TUBERCULOSIS [PHTHISIS PULMONALIS]',
#  'GONORRHEA',
#  'GIARDIASIS',
#  'CHOLERA',
#  'CHLAMYDIA',
#  'MENINGITIS',
#  'BABESIOSIS',
#  'PNEUMONIA',
#  'INFLUENZA',
#  'MUMPS',
#  'PELLAGRA',
#  'DENGUE',
#  'LEPROSY']

# %%
from numpy import dtype
import pandas as pd
tabla = pd.read_csv("tycho-mini.csv",sep=",")
fechas = tabla['from_date']
years = []
for year in fechas:
    sp_year = year.split('-')[0]
    int(sp_year)
    years.append(sp_year)
max(years)
min(years)
# Out:
# '1887'

# %%
import numpy as np
import pandas as pd
tabla = pd.read_csv("tycho-mini.csv",sep=",")
fechas = tabla['from_date']
fechaa = tabla['to_date']
diau = []
diad = []
for year in fechas:
    diauno = year.split('-')[2]
    int(diauno)
    diau.append(diauno)

for year in fechaa:
    diados = year.split('-')[2]
    int(diados)
    diad.append(diados)

for num
uno = np.array(diau)
dos = np.array(diad)
res = uno - dos
print(res)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In [13], line 19
#      17 uno = np.array(diau)
#      18 dos = np.array(diad)
# ---> 19 res = uno - dos
#      20 print(res)
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('<U2'), dtype('<U2')) -> None

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import timedelta
tabla = pd.read_csv("tycho-mini.csv",sep=",")
fechas = tabla['from_date']
fechaa = tabla['to_date']
display(fechas[0])
# uno = fechas[0]
# dos = fechaa[0]
# fecha1 = datetime.strptime(uno, '%d-%m-%Y')
# fecha2 = datetime.strptime(dos, '%d-%m-%Y')
# res = fecha2 - fecha1
# display(res)
for fe in range(fechas):
    uno = fechas[0]
    dos = fechaa[0]
    uno = pd.to_datetime(uno)
    dos = pd.to_datetime(dos)
    res = uno - dos
tabla["diferencia"] = dos - uno
display(res)



# tabla[[uno,dos]] = tabla[[uno,dos]].apply(pd.to_datetime) #if conversion required
# diferencia = (tabla[dos] - tabla[uno]).dt.days
# display(diferencia)
# Out:
# '1888-06-10'
# Timedelta('-6 days +00:00:00')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [21], line 22
#      17 res = uno - dos
#      18 display(res)
# ---> 22 tabla[[uno,dos]] = tabla[[uno,dos]].apply(pd.to_datetime) #if conversion required
#      23 diferencia = (tabla[dos] - tabla[uno]).dt.days
#      24 display(diferencia)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
# ...
